# %%
#pip install mlxtend
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ### 1. Data Prepration

# %%
df = pd.read_csv('transactions.csv')
df.head()
# Out:
#    OrderID          ProductName
# 0  SO51176       Road-250 Black
# 1  SO51176     Road Bottle Cage
# 2  SO51177    Touring-2000 Blue
# 3  SO51177     Sport-100 Helmet
# 4  SO51178  Mountain-200 Silver

# %% [markdown]
# ### 2. Basket Ceation

# %%
# Creating the basket matrix
basket = (
    df
    .groupby(['OrderID', 'ProductName'])['ProductName']
    .count()
    .unstack()
    .fillna(0)
)

# One_hot encoding
basket = basket.map(lambda x: 1 if x > 0 else 0)

# Convert to boolean(Apriori needs boolean values)
basket = basket.astype(bool)

basket.head()
# Out:
# ProductName  AWC Logo Cap  All-Purpose Bike Stand  Bike Wash - Dissolver  \
# OrderID
# SO51176             False                   False                  False
# SO51177             False                   False                  False
# SO51178             False                   False                  False
# SO51179             False                    True                  False
# SO51180             False                   False                  False
#
# ProductName  Classic Vest  Fender Set - Mountain  HL Mountain Tire  \
# OrderID
# SO51176             False                  False             False
# SO51177             False                  False             False
# SO51178             False                  False             False
# SO51179             False                  False             False
# SO51180             False                  False             False
#
# ProductName  HL Road Tire  Half-Finger Gloves  Hitch Rack - 4-Bike  \
# OrderID
# SO51176             False               False                False
# SO51177             False               False                False
# SO51178             False               False                False
# SO51179              True               False                False
# SO51180             False               False                False
#
# ProductName  Hydration Pack - 70 oz.  ...  Sport-100 Helmet  Touring Tire  \
# OrderID                               ...
# SO51176                        False  ...             False         False
# SO51177                        False  ...              True         False
# SO51178                        False  ...             False         False
# SO51179                        False  ...             False         False
# SO51180                        False  ...              True         False
#
# ProductName  Touring Tire Tube  Touring-1000 Blue  Touring-1000 Yellow  \
# OrderID
# SO51176                  False              False                False
# SO51177                  False              False                False
# SO51178                  False              False                False
# SO51179                  False              False                False
# SO51180                  False              False                False
#
# ProductName  Touring-2000 Blue  Touring-3000 Blue  Touring-3000 Yellow  \
# OrderID
# SO51176                  False              False                False
# SO51177                   True              False                False
# SO51178                  False              False                False
# SO51179                  False              False                False
# SO51180                  False              False                False
#
# ProductName  Water Bottle - 30 oz.  Women's Mountain Shorts
# OrderID
# SO51176                      False                    False
# SO51177                      False                    False
# SO51178                       True                    False
# SO51179                      False                    False
# SO51180                       True                    False
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 3. Aprori

# %%
frequent_itemsets = apriori(
    basket,
    min_support=0.02,
    use_colnames=True
)

# %% [markdown]
# ### 4. Association Rules

# %%
rules = association_rules(
    frequent_itemsets,
    metric="lift",
    min_threshold=1
)

# Filter Rules
rules_filtered = rules[
    (rules["confidence"] >= 0.5) &
    (rules["lift"] >= 1.5) &
    (rules["support"] >= 0.01)
].copy()

rules_filtered = rules_filtered[[
    "antecedents",
    "consequents",
    "support",
    "confidence",
    "lift"
]]

# Format antecedents and consequents as strings
rules_filtered["antecedents"] = rules_filtered["antecedents"].apply(lambda x: ", ".join(map(str, x)))
rules_filtered["consequents"] = rules_filtered["consequents"].apply(lambda x: ", ".join(map(str, x)))

# Sort the filtered rules
rules_filtered = rules_filtered.sort_values(
    by=["confidence", "lift"],
    ascending=False
)

rules_filtered
# Out:
#                                antecedents            consequents   support  \
# 65   Road-750 Black, Water Bottle - 30 oz.       Road Bottle Cage  0.026958
# 70      Sport-100 Helmet, Road Bottle Cage  Water Bottle - 30 oz.  0.021066
# 52                            Touring Tire      Touring Tire Tube  0.044911
# 40                        Road Bottle Cage  Water Bottle - 30 oz.  0.084542
# 55      Sport-100 Helmet, HL Mountain Tire     Mountain Tire Tube  0.022400
# 28                    Mountain Bottle Cage  Water Bottle - 30 oz.  0.094047
# 64        Road-750 Black, Road Bottle Cage  Water Bottle - 30 oz.  0.026958
# 60  Sport-100 Helmet, Mountain Bottle Cage  Water Bottle - 30 oz.  0.026235
# 12                            HL Road Tire         Road Tire Tube  0.033128
# 22                        ML Mountain Tire     Mountain Tire Tube  0.043133
# 7                         HL Mountain Tire     Mountain Tire Tube  0.053193
# 24                            ML Road Tire         Road Tire Tube  0.033684
# 17                        LL Mountain Tire     Mountain Tire Tube  0.026569
# 20                            LL Road Tire         Road Tire Tube  0.030849
# 53                       Touring Tire Tube           Touring Tire  0.044911
#
#     confidence       lift
# 65    1.000000  10.551906
# 70    1.000000   4.584862
# 52    0.940629  12.370504
# 40    0.892082   4.090074
# 55    0.891593   5.420969
# 28    0.868583   3.982334
# 64    0.867621   3.977922
# 60    0.838366   3.843792
# 12    0.787318   6.209840
# 22    0.771372   4.690013
# 7     0.752358   4.574411
# 24    0.739024   5.828929
# 17    0.648575   3.943399
# 20    0.601952   4.747796
# 53    0.590643  12.370504

# %%
# rules_filtered.to_csv("market_basket_rules.csv", index=False)
